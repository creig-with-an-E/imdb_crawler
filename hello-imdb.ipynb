# %%
# %config IPCompleter.greedy=True

# %%
# first attempt playing BeautifulSoup

# %%
from requests import get
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'http://www.imdb.com/search/title?release_date=2017&sort=num_votes,desc&page=1'
response = get(url)
html_soup = BeautifulSoup(response.text,'html.parser')

# %%
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
movie_containers = html_soup.find_all('div', class_ = 'lister-item mode-advanced')
print(len(movie_containers))
# Out:
# 50

# %%
# scraped data\

names = []
years = []
imdb_ratings = []
meta_scores = []
votes = []

for container in movie_containers:
    name = container.h3.a.text
    names.append(name)
    
    year = container.h3.find('span', class_='lister-item-year').text
    years.append(year)
    
    imdb = float(container.strong.text)
    imdb_ratings.append(imdb)
    
    if container.find('span', class_='metascore'):
        m_score = container.find('span', class_ = 'metascore').text
    else:
        m_score = 0
    meta_scores.append(int(m_score))

# %%
names[0]
years[0]
meta_scores[0]
# Out:
# 77

# %%
test_df = pd.DataFrame({
    'movie':names,
    'year':years,
    'metascore': meta_scores
})

# %%
print(test_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   movie      50 non-null     object
#  1   year       50 non-null     object
#  2   metascore  50 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.3+ KB
# None

# %%
test_df
# Out:
#                                                movie         year  metascore
# 0                                              Logan       (2017)         77
# 1                                     Thor: Ragnarok       (2017)         74
# 2                     Guardians of the Galaxy Vol. 2       (2017)         67
# 3            Star Wars: Episode VIII - The Last Jedi       (2017)         84
# 4                                       Wonder Woman       (2017)         76
# 5                                            Dunkirk       (2017)         94
# 6                             Spider-Man: Homecoming       (2017)         73
# 7                                            Get Out   (I) (2017)         85
# 8                                                 It   (I) (2017)         69
# 9                                  Blade Runner 2049       (2017)         81
# 10                                       Baby Driver       (2017)         86
# 11         Three Billboards Outside Ebbing, Missouri       (2017)         88
# 12                                    Justice League       (2017)         45
# 13                                The Shape of Water       (2017)         87
# 14                              John Wick: Chapter 2       (2017)         75
# 15                                              Coco   (I) (2017)         81
# 16                    Jumanji: Welcome to the Jungle       (2017)         58
# 17                                  La Casa de Papel     (2017– )          0
# 18                              Beauty and the Beast   (I) (2017)         65
# 19                                Kong: Skull Island       (2017)         62
# 20                       Kingsman: The Golden Circle       (2017)         44
# 21  Pirates of the Caribbean: Dead Men Tell No Tales       (2017)         39
# 22                                   Alien: Covenant       (2017)         65
# 23                                    13 Reasons Why  (2017–2020)          0
# 24                                              Dark  (2017–2020)          0
# 25                                         Lady Bird       (2017)         94
# 26                              The Greatest Showman       (2017)         48
# 27                    War for the Planet of the Apes       (2017)         82
# 28                      Murder on the Orient Express       (2017)         52
# 29                                              Life   (I) (2017)         54
# 30                           The Fate of the Furious       (2017)         56
# 31                              Call Me by Your Name       (2017)         93
# 32                                        Mindhunter     (2017– )          0
# 33                                        Wind River       (2017)         73
# 34                                Ghost in the Shell       (2017)         52
# 35                  King Arthur: Legend of the Sword       (2017)         41
# 36                                           Mother!       (2017)         75
# 37                            The Hitman's Bodyguard       (2017)         47
# 38                                      The Punisher  (2017–2019)          0
# 39                                          I, Tonya       (2017)         77
# 40                                     Atomic Blonde       (2017)         63
# 41                                         The Mummy       (2017)         34
# 42                                             Ozark     (2017– )          0
# 43                                      Darkest Hour       (2017)         75
# 44                                            Bright   (I) (2017)         29
# 45                               The Handmaid's Tale     (2017– )          0
# 46       Valerian and the City of a Thousand Planets       (2017)         51
# 47                                          Baywatch       (2017)         37
# 48                                     American Made       (2017)         65
# 49                                   Big Little Lies  (2017–2019)          0
